# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sys

from mlxtend import __version__ as mlxtend_version
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules

from collections import defaultdict
from scipy.stats import pearsonr

DATASET_FOLDER = "dataset/"

# %%
artists = pd.read_csv(DATASET_FOLDER + 'artists.csv', sep=';')
tracks = pd.read_csv(DATASET_FOLDER + 'tracks.csv', sep=',')

print(artists.head())
# Out:
#      id_author           name gender  birth_date birth_place nationality  \
# 0  ART82291002       99 posse      M         NaN         NaN         NaN
# 1  ART53496045  achille lauro      M  1990-07-11      Verona      Italia
# 2  ART18853907           alfa      M         NaN         NaN         NaN
# 3  ART64265460      anna pepe      F         NaN         NaN         NaN
# 4  ART75741740    articolo 31      M         NaN         NaN         NaN
#
#                             description active_start  active_end province  \
# 0              gruppo musicale italiano   1991-01-01         NaN      NaN
# 1  cantautore e rapper italiano (1990-)   2012-01-01         NaN   Verona
# 2                                   NaN          NaN         NaN      NaN
# 3                                   NaN          NaN         NaN      NaN
# 4      gruppo musicale hip hop italiano   1990-01-01         NaN      NaN
#
#    region country   latitude  longitude
# 0     NaN     NaN        NaN        NaN
# 1  Veneto  Italia  45.442498  10.985738
# 2     NaN     NaN        NaN        NaN
# 3     NaN     NaN        NaN        NaN
# 4     NaN     NaN        NaN        NaN

# %%
print(tracks.head())
# Out:
#          id    id_artist    name_artist  \
# 0  TR934808  ART04205421  Rosa Chemical
# 1  TR760029  ART04205421  Rosa Chemical
# 2  TR916821  ART04205421  Rosa Chemical
# 3  TR480968  ART04205421  Rosa Chemical
# 4  TR585039  ART04205421  Rosa Chemical
#
#                                           full_title         title  \
# 0    ​polka 2 :-/ by Rosa Chemical (Ft. Ernia & Guè)  ​polka 2 :-/
# 1         POLKA by Rosa Chemical (Ft. Thelonious B.)         POLKA
# 2  ​britney ;-) by Rosa Chemical (Ft. MamboLosco ...  ​britney ;-)
# 3                  CEO by Rosa Chemical (Ft. Taxi B)           CEO
# 4                LONDRA by Rosa Chemical (Ft. Rkomi)        LONDRA
#
#       featured_artists primary_artist language              album  \
# 0           Ernia, Guè  Rosa Chemical       pl   FOREVER AND EVER
# 1        Thelonious B.  Rosa Chemical       en   FOREVER AND EVER
# 2  MamboLosco, RADICAL  Rosa Chemical       en   FOREVER AND EVER
# 3               Taxi B  Rosa Chemical       it  OKAY OKAY !! - EP
# 4                Rkomi  Rosa Chemical       en   FOREVER AND EVER
#
#    stats_pageviews  ...  album_type  disc_number track_number duration_ms  \
# 0         196033.0  ...       album          1.0          3.0    207761.0
# 1         164450.0  ...       album          1.0          3.0    207761.0
# 2          58313.0  ...       album          1.0          1.0    193544.0
# 3          39890.0  ...      single          1.0          2.0    169000.0
# 4          35432.0  ...       album          1.0          8.0    194779.0
#
#   explicit  popularity                                        album_image  \
# 0     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 1     True        46.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 2     True        39.0  https://i.scdn.co/image/ab67616d0000b2736d5e14...
# 3     True        47.0  https://i.scdn.co/image/ab67616d0000b27367c03d...
# 4     True        41.0  https://i.scdn.co/image/ab67616d0000b273fcdb60...
#
#     id_album                                             lyrics  \
# 0  ALB115557  Oplà, ah\nBdope, chiama due b—\n\nMi candidere...
# 1  ALB115557  Greg Willen, non dormire\n(Brr-poh)\n\nT-T-Tro...
# 2  ALB115557  Mothz\nYeah, yeah, yeah-yeah\nBdope, chiama du...
# 3  ALB730959  Designer sui vestiti penso di essere un outlet...
# 4  ALB436151  Bdope (Yeah)\n\nVuole solo me, non fare la gel...
#
#    modified_popularity
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
#
# [5 rows x 45 columns]

# %%
print(len(tracks),
len(artists))
# Out:
# 11166 104

# %%
artists_p = artists.add_prefix("artist_")
tracks_p = tracks.add_prefix("track_")

merged = tracks_p.merge(
    artists_p,
    how="left",
    left_on="track_id_artist",
    right_on="artist_id_author"
)

track_cols = [c for c in merged.columns if c.startswith("track_")]
artist_cols = [c for c in merged.columns if c.startswith("artist_")]

print(merged.head())
# Out:
#    track_id track_id_artist track_name_artist  \
# 0  TR934808     ART04205421     Rosa Chemical
# 1  TR760029     ART04205421     Rosa Chemical
# 2  TR916821     ART04205421     Rosa Chemical
# 3  TR480968     ART04205421     Rosa Chemical
# 4  TR585039     ART04205421     Rosa Chemical
#
#                                     track_full_title   track_title  \
# 0    ​polka 2 :-/ by Rosa Chemical (Ft. Ernia & Guè)  ​polka 2 :-/
# 1         POLKA by Rosa Chemical (Ft. Thelonious B.)         POLKA
# 2  ​britney ;-) by Rosa Chemical (Ft. MamboLosco ...  ​britney ;-)
# 3                  CEO by Rosa Chemical (Ft. Taxi B)           CEO
# 4                LONDRA by Rosa Chemical (Ft. Rkomi)        LONDRA
#
#   track_featured_artists track_primary_artist track_language  \
# 0             Ernia, Guè        Rosa Chemical             pl
# 1          Thelonious B.        Rosa Chemical             en
# 2    MamboLosco, RADICAL        Rosa Chemical             en
# 3                 Taxi B        Rosa Chemical             it
# 4                  Rkomi        Rosa Chemical             en
#
#          track_album  track_stats_pageviews  ...  artist_birth_place  \
# 0   FOREVER AND EVER               196033.0  ...          Grugliasco
# 1   FOREVER AND EVER               164450.0  ...          Grugliasco
# 2   FOREVER AND EVER                58313.0  ...          Grugliasco
# 3  OKAY OKAY !! - EP                39890.0  ...          Grugliasco
# 4   FOREVER AND EVER                35432.0  ...          Grugliasco
#
#    artist_nationality                    artist_description  \
# 0              Italia  rapper e cantautore italiano (1998-)
# 1              Italia  rapper e cantautore italiano (1998-)
# 2              Italia  rapper e cantautore italiano (1998-)
# 3              Italia  rapper e cantautore italiano (1998-)
# 4              Italia  rapper e cantautore italiano (1998-)
#
#   artist_active_start artist_active_end  artist_province  artist_region  \
# 0          2015-01-01               NaN           Torino       Piemonte
# 1          2015-01-01               NaN           Torino       Piemonte
# 2          2015-01-01               NaN           Torino       Piemonte
# 3          2015-01-01               NaN           Torino       Piemonte
# 4          2015-01-01               NaN           Torino       Piemonte
#
#    artist_country  artist_latitude  artist_longitude
# 0          Italia        45.068046           7.57762
# 1          Italia        45.068046           7.57762
# 2          Italia        45.068046           7.57762
# 3          Italia        45.068046           7.57762
# 4          Italia        45.068046           7.57762
#
# [5 rows x 59 columns]

# %%
print(merged.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11166 entries, 0 to 11165
# Data columns (total 59 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track_id                    11166 non-null  object
#  1   track_id_artist             11166 non-null  object
#  2   track_name_artist           11166 non-null  object
#  3   track_full_title            11166 non-null  object
#  4   track_title                 11166 non-null  object
#  5   track_featured_artists      3517 non-null   object
#  6   track_primary_artist        11166 non-null  object
#  7   track_language              11061 non-null  object
#  8   track_album                 9652 non-null   object
#  9   track_stats_pageviews       4642 non-null   float64
#  10  track_swear_IT              11166 non-null  int64
#  11  track_swear_EN              11166 non-null  int64
#  12  track_swear_IT_words        11166 non-null  object
#  13  track_swear_EN_words        11166 non-null  object
#  14  track_year                  10766 non-null  object
#  15  track_month                 9969 non-null   float64
#  16  track_day                   9843 non-null   float64
#  17  track_n_sentences           11090 non-null  float64
#  18  track_n_tokens              11090 non-null  float64
#  19  track_tokens_per_sent       11090 non-null  float64
#  20  track_char_per_tok          11090 non-null  float64
#  21  track_lexical_density       11090 non-null  float64
#  22  track_avg_token_per_clause  11090 non-null  float64
#  23  track_bpm                   11102 non-null  float64
#  24  track_centroid              11102 non-null  float64
#  25  track_rolloff               11102 non-null  float64
#  26  track_flux                  11102 non-null  float64
#  27  track_rms                   11102 non-null  float64
#  28  track_zcr                   11102 non-null  float64
#  29  track_flatness              11102 non-null  float64
#  30  track_spectral_complexity   11102 non-null  float64
#  31  track_pitch                 11102 non-null  float64
#  32  track_loudness              11102 non-null  float64
#  33  track_album_name            11088 non-null  object
#  34  track_album_release_date    11088 non-null  object
#  35  track_album_type            11088 non-null  object
#  36  track_disc_number           11088 non-null  float64
#  37  track_track_number          11088 non-null  float64
#  38  track_duration_ms           11088 non-null  float64
#  39  track_explicit              11088 non-null  object
#  40  track_popularity            11164 non-null  object
#  41  track_album_image           11088 non-null  object
#  42  track_id_album              11088 non-null  object
#  43  track_lyrics                11163 non-null  object
#  44  track_modified_popularity   11166 non-null  bool
#  45  artist_id_author            11166 non-null  object
#  46  artist_name                 11166 non-null  object
#  47  artist_gender               11166 non-null  object
#  48  artist_birth_date           8759 non-null   object
#  49  artist_birth_place          8588 non-null   object
#  50  artist_nationality          8557 non-null   object
#  51  artist_description          10028 non-null  object
#  52  artist_active_start         6565 non-null   object
#  53  artist_active_end           0 non-null      float64
#  54  artist_province             8467 non-null   object
#  55  artist_region               8024 non-null   object
#  56  artist_country              8467 non-null   object
#  57  artist_latitude             8588 non-null   float64
#  58  artist_longitude            8588 non-null   float64
# dtypes: bool(1), float64(25), int64(2), object(31)
# memory usage: 5.0+ MB
# None

# %%
merged.drop(columns=["artist_active_end"], inplace=True)

# %%
for i in merged.columns:
    n= merged[i].isnull().sum()
    print(f"{i}: {n} null")
# Out:
# track_id: 0 null
# track_id_artist: 0 null
# track_name_artist: 0 null
# track_full_title: 0 null
# track_title: 0 null
# track_featured_artists: 7649 null
# track_primary_artist: 0 null
# track_language: 105 null
# track_album: 1514 null
# track_stats_pageviews: 6524 null
# track_swear_IT: 0 null
# track_swear_EN: 0 null
# track_swear_IT_words: 0 null
# track_swear_EN_words: 0 null
# track_year: 400 null
# track_month: 1197 null
# track_day: 1323 null
# track_n_sentences: 76 null
# track_n_tokens: 76 null
# track_tokens_per_sent: 76 null
# track_char_per_tok: 76 null
# track_lexical_density: 76 null
# track_avg_token_per_clause: 76 null
# track_bpm: 64 null
# track_centroid: 64 null
# track_rolloff: 64 null
# track_flux: 64 null
# track_rms: 64 null
# track_zcr: 64 null
# track_flatness: 64 null
# track_spectral_complexity: 64 null
# track_pitch: 64 null
# track_loudness: 64 null
# track_album_name: 78 null
# track_album_release_date: 78 null
# track_album_type: 78 null
# track_disc_number: 78 null
# track_track_number: 78 null
# track_duration_ms: 78 null
# track_explicit: 78 null
# track_popularity: 2 null
# track_album_image: 78 null
# track_id_album: 78 null
# track_lyrics: 3 null
# track_modified_popularity: 0 null
# artist_id_author: 0 null
# artist_name: 0 null
# artist_gender: 0 null
# artist_birth_date: 2407 null
# artist_birth_place: 2578 null
# artist_nationality: 2609 null
# artist_description: 1138 null
# artist_active_start: 4601 null
# artist_province: 2699 null
# artist_region: 3142 null
# artist_country: 2699 null
# artist_latitude: 2578 null
# artist_longitude: 2578 null

# %%
duplicated_tracks= len(merged) - len(merged.track_id.unique())
print('Numero canzoni duplicate:', duplicated_tracks)
# Out:
# Numero canzoni duplicate: 73

# %%
dup_ids = merged.loc[merged["track_id"].duplicated(keep=False), "track_id"]
rows_with_same_track_id = merged[merged["track_id"].isin(dup_ids)].sort_values("track_id")
rows_with_same_track_id
# Out:
# c:\Users\ludol\miniconda3\envs\myenv\Lib\site-packages\pandas\core\algorithms.py:522: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   common = np.find_common_type([values.dtype, comps_array.dtype], [])
#        track_id track_id_artist track_name_artist  \
# 4240   TR108862     ART56320683     Bassi Maestro
# 7786   TR108862     ART07127070       Noyz Narcos
# 3199   TR135764     ART73965015            Ghemon
# 5847   TR135764     ART86549066        Emis Killa
# 8104   TR190585     ART78209349              Coez
# ...         ...             ...               ...
# 2474   TR980497     ART48537029          Mistaman
# 4190   TR987615     ART56320683     Bassi Maestro
# 1318   TR987615     ART63613967  Massimo Pericolo
# 10375  TR997536     ART91352277      Mondo Marcio
# 9952   TR997536     ART78358659             Nitro
#
#                                        track_full_title  \
# 4240                         Sushi Bar by Bassi Maestro
# 7786                    SPINE by Noyz Narcos (Ft. Coez)
# 3199                   Nessuno vale quanto te by Ghemon
# 5847          Giovani eroi by Emis Killa (Ft. Not Good)
# 8104     Nei treni la notte by Coez (Ft. Frah Quintale)
# ...                                                 ...
# 2474                        Te-le-co-man-do by Mistaman
# 4190   Django Muzik by Bassi Maestro (Ft. Mondo Marcio)
# 1318                      Polo Nord by Massimo Pericolo
# 10375                         Vida Loca by Mondo Marcio
# 9952                       L’oracolo di Selfie by Nitro
#
#                   track_title track_featured_artists track_primary_artist  \
# 4240                Sushi Bar                    NaN        Bassi Maestro
# 7786                    SPINE                   Coez          Noyz Narcos
# 3199   Nessuno vale quanto te                    NaN               Ghemon
# 5847             Giovani eroi               Not Good           Emis Killa
# 8104       Nei treni la notte          Frah Quintale                 Coez
# ...                       ...                    ...                  ...
# 2474          Te-le-co-man-do                    NaN             Mistaman
# 4190             Django Muzik           Mondo Marcio        Bassi Maestro
# 1318                Polo Nord                    NaN     Massimo Pericolo
# 10375               Vida Loca                    NaN         Mondo Marcio
# 9952      L’oracolo di Selfie                    NaN                Nitro
#
#       track_language             track_album  track_stats_pageviews  ...  \
# 4240              en                Sushi EP                    NaN  ...
# 7786              cs          VIRUS (Deluxe)                19050.0  ...
# 3199              it                ORCHIdee                 7182.0  ...
# 5847              it      Keta Music, Vol. 3                13155.0  ...
# 8104              it      From The Rooftop 2                    NaN  ...
# ...              ...                     ...                    ...  ...
# 2474              it         Anni senza fine                    NaN  ...
# 4190              it         Guarda In Cielo                    NaN  ...
# 1318              en                     NaN                77510.0  ...
# 10375             co                   UOMO!                 5075.0  ...
# 9952              it  Suicidol - Post Mortem                21270.0  ...
#
#        artist_birth_date  artist_birth_place artist_nationality  \
# 4240          1973-08-03              Milano             Italia
# 7786          1979-12-15                Roma             Italia
# 3199          1982-04-01            Avellino             Italia
# 5847          1989-11-14           Vimercate             Italia
# 8104          1983-07-11    Nocera Inferiore             Italia
# ...                  ...                 ...                ...
# 2474          1976-09-11             Treviso             Italia
# 4190          1973-08-03              Milano             Italia
# 1318          1993-11-30           Gallarate             Italia
# 10375         1986-12-01              Milano             Italia
# 9952          1993-02-11             Vicenza             Italia
#
#                                       artist_description artist_active_start  \
# 4240   rapper, disc jockey, beatmaker e produttore di...          1988-01-01
# 7786   rapper e produttore discografico italiano (1979-)          1996-01-01
# 3199       rapper, cantante e stand up comedian italiano          1996-01-01
# 5847                             rapper italiano (1989-)          2006-01-01
# 8104                cantautore e rapper italiano (1983-)          2002-01-01
# ...                                                  ...                 ...
# 2474                                     rapper italiano                 NaN
# 4190   rapper, disc jockey, beatmaker e produttore di...          1988-01-01
# 1318                         criminale e rapper italiano                 NaN
# 10375          rapper e produttore discografico italiano                 NaN
# 9952                             rapper italiano (1993-)          2007-01-01
#
#              artist_province  artist_region  artist_country  artist_latitude  \
# 4240                  Milano      Lombardia          Italia        45.464194
# 7786                    Roma          Lazio          Italia        41.893320
# 3199                Avellino       Campania          Italia        40.996545
# 5847   Monza e della Brianza      Lombardia          Italia        45.613963
# 8104                 Salerno       Campania          Italia        40.747213
# ...                      ...            ...             ...              ...
# 2474                 Treviso         Veneto          Italia        45.806691
# 4190                  Milano      Lombardia          Italia        45.464194
# 1318                  Varese      Lombardia          Italia        45.659895
# 10375                 Milano      Lombardia          Italia        45.464194
# 9952                 Vicenza         Veneto          Italia        45.634859
#
#        artist_longitude
# 4240           9.189635
# 7786          12.482932
# 3199          15.140569
# 5847           9.370060
# 8104          14.643320
# ...                 ...
# 2474          12.206316
# 4190           9.189635
# 1318           8.793201
# 10375          9.189635
# 9952          11.406354
#
# [144 rows x 58 columns]

# %%
pair_cols = ["track_id", "track_title"]

duplicate_mask = merged.duplicated(subset=pair_cols, keep=False)
duplicate_rows = merged.loc[duplicate_mask, pair_cols]

duplicate_pairs = duplicate_rows.drop_duplicates()

rows_with_same_track_and_artist = (
    merged.merge(duplicate_pairs, on=pair_cols)
          .sort_values(pair_cols)
 )

rows_with_same_track_and_artist
# Out:
#    track_id track_id_artist track_name_artist  \
# 0  TR367132     ART20729624            Madame
# 1  TR367132     ART20729624            Madame
# 2  TR367132     ART20729624            Madame
# 3  TR367132     ART20729624            Madame
#
#                            track_full_title track_title  \
# 0  BUGIE by Madame (Ft. Carl Brave & Rkomi)       BUGIE
# 1  BUGIE by Madame (Ft. Carl Brave & Rkomi)       BUGIE
# 2                        ​sentimi by Madame    ​sentimi
# 3                        ​sentimi by Madame    ​sentimi
#
#   track_featured_artists track_primary_artist track_language track_album  \
# 0      Rkomi, Carl Brave               Madame             it      MADAME
# 1      Rkomi, Carl Brave               Madame             it      MADAME
# 2                    NaN               Madame             it         NaN
# 3                    NaN               Madame             it         NaN
#
#    track_stats_pageviews  ...  artist_birth_date  artist_birth_place  \
# 0                36960.0  ...         2002-01-16             Vicenza
# 1                36960.0  ...         2002-01-16             Vicenza
# 2                14015.0  ...         2002-01-16             Vicenza
# 3                14015.0  ...         2002-01-16             Vicenza
#
#   artist_nationality                     artist_description  \
# 0             Italia  cantautrice e rapper italiana (2002-)
# 1             Italia  cantautrice e rapper italiana (2002-)
# 2             Italia  cantautrice e rapper italiana (2002-)
# 3             Italia  cantautrice e rapper italiana (2002-)
#
#   artist_active_start  artist_province  artist_region  artist_country  \
# 0          2018-01-01          Vicenza         Veneto          Italia
# 1          2018-01-01          Vicenza         Veneto          Italia
# 2          2018-01-01          Vicenza         Veneto          Italia
# 3          2018-01-01          Vicenza         Veneto          Italia
#
#    artist_latitude  artist_longitude
# 0        45.634859         11.406354
# 1        45.634859         11.406354
# 2        45.634859         11.406354
# 3        45.634859         11.406354
#
# [4 rows x 58 columns]

# %%
pair_cols = ["track_id", "track_title"]

merged = merged.drop_duplicates(subset=pair_cols, keep="first")

print( len(merged))
# Out:
# 11164

# %%
unique= []
for _, row in merged.iterrows():
    name_artist = str(row["track_name_artist"]).lower()
    artist_name = str(row["artist_name"]).lower()
    primary_artist = str(row["track_primary_artist"]).lower()
    triple = (name_artist, artist_name, primary_artist)

    if name_artist != artist_name or name_artist != primary_artist or artist_name != primary_artist:
        if triple not in unique:
            unique.append(triple)
print(unique)
# Out:
# [('guè', 'guè pequeno', 'guè'), ('chadia', 'chadia rodriguez', 'chadia'), ('’o zulù', 'o zulù', '’o zulù'), ('m¥ss keta', 'miss keta', 'm¥ss keta'), ('dargen d’amico', 'dargen d_amico', 'dargen d’amico'), ('mr.rain', 'mr. rain', 'mr.rain'), ('highsnob', 'mike24', 'highsnob'), ('anna', 'anna pepe', 'anna'), ('samuel costa', 'samuel heron', 'samuel costa'), ('joey (ita)', 'joey funboy', 'joey (ita)')]

# %%
merged['track_album_release_date'].head(30)
# Out:
# 0     2021-04-09
# 1     2021-04-09
# 2     2021-04-09
# 3     2025-05-16
# 4     2020-05-28
# 5     2020-05-28
# 6     2020-05-28
# 7     2020-05-28
# 8     2023-02-09
# 9     2020-05-28
# 10    2022-06-02
# 11    2020-05-28
# 12    2020-05-28
# 13    2020-05-28
# 14    2021-04-09
# 15    2020-05-28
# 16    2020-05-28
# 17    2020-05-28
# 18    2020-05-28
# 19    2021-04-09
# 20    2021-04-09
# 21    2019-06-07
# 22    2025-05-16
# 23    2020-10-02
# 24    2020-10-02
# 25    2019-09-20
# 26    2019-03-08
# 27    2019-03-08
# 28    2019-03-08
# 29    2019-03-08
# Name: track_album_release_date, dtype: object

# %%
float_cols = merged.select_dtypes(include=['float64']).columns
for col in float_cols:
    series = pd.to_numeric(merged[col], errors="coerce")
    mean = series.mean()
    std_dev = series.std()
    outliers = series[series.sub(mean).abs() > 5 * std_dev]
    count= len(outliers)
    print(f"{col}: {count} outliers " )
# Out:
# track_stats_pageviews: 25 outliers
# track_month: 0 outliers
# track_day: 0 outliers
# track_n_sentences: 18 outliers
# track_n_tokens: 17 outliers
# track_tokens_per_sent: 24 outliers
# track_char_per_tok: 81 outliers
# track_lexical_density: 57 outliers
# track_avg_token_per_clause: 27 outliers
# track_bpm: 1 outliers
# track_centroid: 1 outliers
# track_rolloff: 10 outliers
# track_flux: 5 outliers
# track_rms: 2 outliers
# track_zcr: 9 outliers
# track_flatness: 223 outliers
# track_spectral_complexity: 0 outliers
# track_pitch: 2 outliers
# track_loudness: 3 outliers
# track_disc_number: 173 outliers
# track_track_number: 11 outliers
# track_duration_ms: 25 outliers
# artist_latitude: 0 outliers
# artist_longitude: 0 outliers

# %%
merged['track_year'].unique()
# Out:
# array(['2021.0', '2020.0', '2019.0', '2072', '2098', '2023.0', '2022.0',
#        '1917', '1920', '2025.0', '2018.0', '1901', '2052', '2024.0',
#        '2081', '2060', '2015.0', '1933', '1928', '2057', '2016.0', '2078',
#        '2058', '1963', '2017.0', '1908', '2062', '2051', '2074', '2079',
#        '1942', '1969', '2064', '2068', '1961', '2054', '1941', '1951',
#        '1906', '2084', '1938', '2070', '1918', nan, '1944', '2097',
#        '1903', '1924', '2089', '2095', '1962', '1934', '2075', '1921',
#        '1935', '1912', '1937', '1947', '1929', '1939', '2080', '1949',
#        '2076', '2093', '2085', '1967', '2100', '1911', '2053', '2014.0',
#        '1900', '2090', '2063', '1930', '2012.0', '2013.0', '2073', '2083',
#        '1958', '1954', '2099', '2088', '2087', '1952', '2056', '2077',
#        '1957', '2067', '2065', '1922', '1936', '2082', 'nPmvFS', '2006.0',
#        '2010.0', '2008.0', '2011.0', '1953', '1955', '2094', '1971',
#        '2059', '2092', '2055', 'MoKKcY', '1948', '1968', '2086', '1932',
#        '2009.0', '2005.0', '1925', '1910', '2004.0', '1909', '1960',
#        '2096', '1999.0', '1966', '2091', '1931', '2071', '1946', '1907',
#        '1915', '2061', '1927', 'PdLLvs', '1919', '2069', '1940', '1959',
#        '1902', 'Tr5ghq', 'FZM9N5', '2002.0', '2007.0', '1998.0', '2000.0',
#        '2066', '1997.0', '3KBIhx', '7arrc9', '1923', '1945', '2003.0',
#        '0S4bYq', 'Ww2RM0', 'YDWvPA', '1965', '1995.0', '1916', 'v9Gs4k',
#        '1956', '1972', '1926', '2001.0', '1904', '1913', '1943', '1914',
#        '1uWHmg', '1964', 's7ujOB', '1993.0', '1996.0', '1994.0', '1992.0',
#        'CeZdpY', '1905', '1950', 'DkWnRx', 'oiiWuy', 'IlHfzv', '1970',
#        'uUsYUb', 'unxIUH', 'iW9Q9J', 'td0lg8', 'fNBiFf', 'RqnJ7g',
#        'VwVFFX', 'Ise7dm', 'vgGgkT', 'QPNIJj', 'BMMnal', 'k2QnmQ',
#        '6R1q9L', 'P03Hkq', 'tMcdp6', 'epqCR2', 'Tl2Dgz', 'uiux8t',
#        'gZ2JDM', 'Gv70wC', '8i0piY'], dtype=object)

# %%
series = pd.to_numeric(merged['track_year'], errors="coerce")
is_float = series.notna() & series.apply(lambda x: isinstance(x, (float, np.floating)))
print(is_float.sum())
print(len(merged['track_year'].notna()))
# Out:
# 10726
# 11164

# %%
merged["artist_active_start_year"] = (
    pd.to_numeric(merged["artist_active_start"].astype(str).str.slice(0, 4), errors="coerce")
    .astype("Int64")
)

# %%
track_year_num = pd.to_numeric(merged["track_year"], errors="coerce")
active_start_year_num = pd.to_numeric(merged["artist_active_start_year"], errors="coerce")
mask = (track_year_num > active_start_year_num) & (track_year_num < 2027)
merged["track_year"] = track_year_num.where(mask, pd.NA)

# %%
merged['track_year'].unique()
# Out:
# array([2021., 2020., 2019.,   nan, 2023., 2022., 2025., 2018., 2024.,
#        2016., 2017., 2014., 2013., 2015., 1999., 2002., 2012., 2007.,
#        1998., 2000., 1997., 2004., 2010., 2006., 2009., 2011., 2008.,
#        2005., 2001., 1993., 1996., 2003., 1994., 1992., 1995.])

# %%
print(merged['track_year'].notna().sum())
# Out:
# 5001

# %%
merged["track_tot_swear_words"] = merged["track_swear_IT"] + merged["track_swear_EN"]
for col_name in ["track_popularity", "track_stats_pageviews", "track_bpm", "track_duration_ms", 
                 "track_lexical_density", "track_year", "track_loudness", "track_tot_swear_words",
                 "track_centroid", "track_flatness"]:
    print(merged[col_name].dtype)
    merged[col_name] = pd.to_numeric(merged[col_name], errors="coerce")
    plt.figure()
    merged[col_name].hist()
    plt.title(col_name)
    plt.xlabel(col_name)
    plt.yscale('log')
    plt.show()

swear_it = pd.to_numeric(merged["track_swear_IT"], errors="coerce")
swear_en = pd.to_numeric(merged["track_swear_EN"], errors="coerce")
plt.figure()
plt.hist([swear_it, swear_en], bins=30, stacked=True, label=["IT", "EN"], alpha=0.8)
plt.title("Swear words (IT vs EN)")
plt.xlabel("Swear words")
plt.ylabel("Count")
plt.legend()
plt.show()
# Out:
# object
# float64
# float64
# float64
# float64
# float64
# float64
# int64
# float64
# float64

# %%
merged['track_popularity'] = pd.to_numeric(merged['track_popularity'], errors="coerce")
pop = merged['track_popularity'].dropna()
pop = pop[pop > 0]  

bins = np.logspace(np.log10(1), np.log10(1e6), 40) 

plt.figure('1')
plt.hist(pop, bins=bins)
plt.xscale('log')
plt.title('Track Popularity')
plt.xlabel('Track Popularity')
plt.xlim(1, 1e6)
# Out:
# (1, 1000000.0)

# %%
merged["track_bumpiness"] = pd.to_numeric(merged["track_spectral_complexity"], errors="coerce") / (
    pd.to_numeric(merged["track_rolloff"], errors="coerce") - pd.to_numeric(merged["track_centroid"], errors="coerce")
)

merged["track_avg_swear_words"] = merged["track_tot_swear_words"] / merged["track_n_tokens"]


merged["artist_birth_year"] = (
    pd.to_numeric(merged["artist_birth_date"].astype(str).str.slice(0, 4), errors="coerce")
    .astype("Int64")
)

merged["track_artist_age"]= merged["track_year"] - merged["artist_birth_year"]

merged["track_tokens_per_sec"] = merged["track_n_tokens"] / (merged["track_duration_ms"] / 1000)

# %%
# Correlation heatmap for numeric columns
corr = merged.select_dtypes(include="number").corr()
plt.figure(figsize=(10, 8))
plt.imshow(corr, cmap="coolwarm", vmin=-1, vmax=1)
plt.colorbar(label="Correlation")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation matrix")
plt.tight_layout()
plt.show()

corr_pairs = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
strong_pairs = corr_pairs.stack().sort_values(ascending=False)
print("Strongly correlated pairs:")
print(strong_pairs[strong_pairs.abs() > 0.5])
# Out:
# Strongly correlated pairs:
# track_rms                  track_loudness               0.995555
# track_rolloff              track_zcr                    0.969097
# artist_active_start_year   artist_birth_year            0.927140
# track_n_sentences          track_n_tokens               0.867736
# track_centroid             track_zcr                    0.864452
# track_tot_swear_words      track_avg_swear_words        0.850804
# track_swear_IT             track_tot_swear_words        0.842228
# track_centroid             track_rolloff                0.775643
# track_n_tokens             track_tokens_per_sec         0.760372
# track_swear_IT             track_avg_swear_words        0.693247
# track_rms                  track_spectral_complexity    0.644292
# track_swear_EN             track_tot_swear_words        0.623791
# track_rms                  track_bumpiness              0.616917
# track_n_sentences          track_tokens_per_sec         0.609353
# track_spectral_complexity  track_loudness               0.608888
# track_loudness             track_bumpiness              0.599506
# track_swear_EN             track_avg_swear_words        0.564019
# track_year                 artist_active_start_year     0.551709
#                            artist_birth_year            0.525355
# track_zcr                  track_bumpiness             -0.503794
# artist_active_start_year   track_artist_age            -0.511536
# track_rolloff              track_bumpiness             -0.569447
# artist_birth_year          track_artist_age            -0.603261
# artist_latitude            artist_longitude            -0.704038
# dtype: float64

# %% [markdown]
# Tra rms e loudness teniamo loudness
# tra rolloff, zcr, e centroid teniamo centroid
# tra n_sentences e n_token teniamo n_tokens
# tra latitude e longitude teniamo latitude
# tra swear words IT ed ENG teniamo IT
